# %% [markdown]
# Making R/Bioconductor tool integration easier in Galaxy
# ======

# %% [markdown]
# This notebook will demonstrate how to use the new `planemo` command `bioc_tool_init` to generate files needed for R/Bioconductor tool integration into Galaxy. It is a companion Jupyter notebook to "A Guide and Best Practices for R/Bioconductor Tool Integration in Galaxy" (doi: TBD).

# %%
planemo bioc_tool_init 
--force 
--tool my_affy_tool_long.xml 
--name "Extract Expression" 
--description " values from CEL Agilent microarray data" 
--rscript my_affy_tool.R 
--example_command "Rscript /path/to/example_affy/my_affy_tool.R --input galaxy_input.CEL --output galaxy_output.txt" 
--help_text "This tool reads in Agilent CEL data and outputs probe expression values." 
--doi "10.1093/bioinformatics/btg405"

# %% [markdown]
# The `bioc_tool_init` command generates a Tool definition XML file based on the supplied arguments and information parsed from the .
